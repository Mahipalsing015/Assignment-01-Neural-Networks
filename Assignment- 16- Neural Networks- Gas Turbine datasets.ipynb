# %%
# Mahipalsing Assignment

# %%
# import libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load datasets
data = pd.read_csv("/Users/mayur/Desktop/Excelr Solution/Assignment-16(Neural Networks)/gas_turbines.csv")
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
# Define X & y
X = data.drop(columns = ['TEY'], axis = 1) 
y = data.iloc[:,7]

# %%
X
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX
# 0      82.722
# 1      82.776
# 2      82.468
# 3      82.670
# 4      82.311
# ...       ...
# 15034  79.559
# 15035  79.917
# 15036  90.912
# 15037  93.227
# 15038  92.498
#
# [15039 rows x 10 columns]

# %%
y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)
X_train_scaled = scale(X_train)
X_test_scaled = scale(X_test)
X_test_scaled
# Out:
# array([[ 0.82623246, -0.43954308, -0.25924569, ...,  0.10039242,
#         -0.3796304 , -0.69217007],
#        [ 0.35282087,  0.23279782,  0.80230139, ..., -1.18541222,
#          0.39149515, -1.09475442],
#        [ 0.32839008, -0.07135639,  0.25312287, ...,  0.01665304,
#         -0.00296896, -0.31891741],
#        ...,
#        [-0.74071701,  0.37687087,  0.43427425, ...,  1.77157829,
#         -1.00127821, -0.4818816 ],
#        [-0.49965786, -0.39151873,  0.64680105, ..., -0.26517949,
#         -0.48137538,  0.12808615],
#        [ 0.13151427,  0.32884652,  0.98830762, ..., -1.40331469,
#          0.13152215, -0.64456466]])

# %%
input_size = len(X.columns)
output_size = 1
hidden_layer_size = 50

model = tf.keras.Sequential([
                                
                               tf.keras.layers.Dense(hidden_layer_size, input_dim = input_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),     
                               tf.keras.layers.Dense(output_size)
    
    
                                ])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate = 0.03)
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['MeanSquaredError'])

# %%
num_epochs = 50
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 2)
model.fit(X_train_scaled, y_train, callbacks = early_stopping, validation_split = 0.1, epochs = num_epochs, verbose = 2)
# Out:
# Epoch 1/50
# 381/381 - 1s - loss: 2827.7275 - mean_squared_error: 2827.7275 - val_loss: 159.9678 - val_mean_squared_error: 159.9678 - 724ms/epoch - 2ms/step
# Epoch 2/50
# 381/381 - 0s - loss: 80.5987 - mean_squared_error: 80.5987 - val_loss: 57.8696 - val_mean_squared_error: 57.8696 - 325ms/epoch - 854us/step
# Epoch 3/50
# 381/381 - 0s - loss: 35.6439 - mean_squared_error: 35.6439 - val_loss: 29.9411 - val_mean_squared_error: 29.9411 - 335ms/epoch - 880us/step
# Epoch 4/50
# 381/381 - 0s - loss: 20.3424 - mean_squared_error: 20.3424 - val_loss: 18.8783 - val_mean_squared_error: 18.8783 - 360ms/epoch - 944us/step
# Epoch 5/50
# 381/381 - 0s - loss: 12.3546 - mean_squared_error: 12.3546 - val_loss: 11.2312 - val_mean_squared_error: 11.2312 - 316ms/epoch - 831us/step
# Epoch 6/50
# 381/381 - 0s - loss: 7.7089 - mean_squared_error: 7.7089 - val_loss: 6.0651 - val_mean_squared_error: 6.0651 - 336ms/epoch - 881us/step
# Epoch 7/50
# 381/381 - 0s - loss: 5.2342 - mean_squared_error: 5.2342 - val_loss: 3.8550 - val_mean_squared_error: 3.8550 - 317ms/epoch - 831us/step
# Epoch 8/50
# 381/381 - 0s - loss: 4.0045 - mean_squared_error: 4.0045 - val_loss: 3.5821 - val_mean_squared_error: 3.5821 - 326ms/epoch - 855us/step
# Epoch 9/50
# 381/381 - 0s - loss: 3.2823 - mean_squared_error: 3.2823 - val_loss: 2.6953 - val_mean_squared_error: 2.6953 - 317ms/epoch - 833us/step
# Epoch 10/50
# 381/381 - 0s - loss: 2.4131 - mean_squared_error: 2.4131 - val_loss: 1.9675 - val_mean_squared_error: 1.9675 - 325ms/epoch - 853us/step
# Epoch 11/50
# 381/381 - 0s - loss: 2.0988 - mean_squared_error: 2.0988 - val_loss: 1.9755 - val_mean_squared_error: 1.9755 - 335ms/epoch - 880us/step
# Epoch 12/50
# 381/381 - 0s - loss: 1.7569 - mean_squared_error: 1.7569 - val_loss: 1.8835 - val_mean_squared_error: 1.8835 - 335ms/epoch - 878us/step
# Epoch 13/50
# 381/381 - 0s - loss: 1.4909 - mean_squared_error: 1.4909 - val_loss: 1.4945 - val_mean_squared_error: 1.4945 - 351ms/epoch - 922us/step
# Epoch 14/50
# 381/381 - 0s - loss: 1.5455 - mean_squared_error: 1.5455 - val_loss: 1.5897 - val_mean_squared_error: 1.5897 - 303ms/epoch - 795us/step
# Epoch 15/50
# 381/381 - 0s - loss: 1.4350 - mean_squared_error: 1.4350 - val_loss: 2.3653 - val_mean_squared_error: 2.3653 - 320ms/epoch - 840us/step

# %%
test_loss, mean_squared_error = model.evaluate(X_test_scaled, y_test)
# Out:
# 47/47 [==============================] - 0s 852us/step - loss: 2.1529 - mean_squared_error: 2.1529

# %%
predictions = model.predict_on_batch(X_test_scaled)

# %%
plt.scatter(y_test, predictions)

# %%
predictions_df = pd.DataFrame()
predictions_df['Actual'] = y_test
predictions_df['Predicted'] = predictions
predictions_df['% Error'] = abs(predictions_df['Actual'] - predictions_df['Predicted'])/predictions_df['Actual']*100
predictions_df.reset_index(drop = True)
# Out:
#       Actual   Predicted   % Error
# 0     134.46  136.161942  1.265760
# 1     111.88  114.036865  1.927838
# 2     133.72  135.889908  1.622725
# 3     133.79  135.484650  1.266649
# 4     110.77  112.488609  1.551512
# ...      ...         ...       ...
# 1499  132.85  133.441101  0.444939
# 1500  125.07  125.583908  0.410896
# 1501  160.95  160.792252  0.098011
# 1502  133.12  134.441818  0.992952
# 1503  111.79  113.071617  1.146451
#
# [1504 rows x 3 columns]

# %%
# Done
